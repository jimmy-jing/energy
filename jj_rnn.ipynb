# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.options.display.max_columns = 50
pd.options.display.max_rows = 5000

# %%
aep = pd.read_csv('./data/AEP_hourly.csv')

# %%
aep.shape
aep.dtypes
aep.head(5)
# Out:
# (121273, 2)
# Datetime     object
# AEP_MW      float64
# dtype: object
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0
# 3  2004-12-31 04:00:00  12517.0
# 4  2004-12-31 05:00:00  12670.0

# %%
aep.Datetime = pd.to_datetime(aep.Datetime)

# %%
aep.isnull().sum()
# Out:
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
aep.sort_values('Datetime', ascending=True,inplace=True)

# %%
aep
# Out:
#                   Datetime   AEP_MW
# 2183   2004-10-01 01:00:00  12379.0
# 2184   2004-10-01 02:00:00  11935.0
# 2185   2004-10-01 03:00:00  11692.0
# 2186   2004-10-01 04:00:00  11597.0
# 2187   2004-10-01 05:00:00  11681.0
# 2188   2004-10-01 06:00:00  12280.0
# 2189   2004-10-01 07:00:00  13692.0
# 2190   2004-10-01 08:00:00  14618.0
# 2191   2004-10-01 09:00:00  14903.0
# 2192   2004-10-01 10:00:00  15118.0
# 2193   2004-10-01 11:00:00  15242.0
# 2194   2004-10-01 12:00:00  15375.0
# 2195   2004-10-01 13:00:00  15404.0
# 2196   2004-10-01 14:00:00  15655.0
# 2197   2004-10-01 15:00:00  15739.0
# 2198   2004-10-01 16:00:00  15739.0
# 2199   2004-10-01 17:00:00  15644.0
# 2200   2004-10-01 18:00:00  15353.0
# 2201   2004-10-01 19:00:00  15034.0
# 2202   2004-10-01 20:00:00  15211.0
# 2203   2004-10-01 21:00:00  15349.0
# 2204   2004-10-01 22:00:00  14837.0
# 2205   2004-10-01 23:00:00  14067.0
# 2206   2004-10-02 00:00:00  13147.0
# 2159   2004-10-02 01:00:00  12260.0
# ...

# %%
plt.figure(figsize=(20,11))
ax = sns.lineplot('Datetime','AEP_MW', data=aep)

# %%
aep['year'] = aep.Datetime.apply(lambda x: x.year)
aep['month'] = aep['Datetime'].apply(lambda x: x.month)

# %%
plt.figure(figsize=(20,11))
ax = sns.lineplot('Datetime','AEP_MW', data=aep[aep.year==2016])

# %%
aep.AEP_MW.describe()
# Out:
# count    121273.000000
# mean      15499.513717
# std        2591.399065
# min        9581.000000
# 25%       13630.000000
# 50%       15310.000000
# 75%       17200.000000
# max       25695.000000
# Name: AEP_MW, dtype: float64
